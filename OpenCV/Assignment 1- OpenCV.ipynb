# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Loading the image

# %%
img = cv2.imread('/home/pranavkdas/Documents/nemo.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.show()

# %% [markdown]
# # Grayscale and Black&White conversion

# %%
grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
bw = cv2.adaptiveThreshold(grayscale,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

titles = ['gray', 'black and white']
images = [grayscale, bw]

plt.figure(figsize=(20,20))
for i in range(2):
    plt.subplot(1,2,i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# **Trying to make black and white image more clearer using Gaussian Blur and Adaptive Thresholding**

# %%
img = cv2.imread('/home/pranavkdas/Documents/nemo.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(grayscale,(5,5),0)
bw = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
laplacian = cv2.Laplacian(bw,cv2.CV_8U)
plt.figure(figsize=(8,8))
plt.title('Black and White')
plt.xticks([]), plt.yticks([])
plt.imshow(bw,'gray')
plt.show()

# %% [markdown]
# # Video capture

# %% [markdown]
# Reading (capture.read()) from a VideoCapture returns a tuple (return value, image).
# With the first item you check wether the reading was successful,
# and if it was then you proceed to use the returned image.

# %% [markdown]
# (cv2.waitKey(1) & 0xFF) == ord('q') is a binary operation which leaves the last 8 bits of the digit entered. If it is equal to the ordinal value of q, then the window is closed

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

while(True):
    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Everything in image from red to blue

# %%
img = cv2.imread('/home/pranavkdas/Documents/nemo.jpg')
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.show()

# %%
mask = cv2.inRange(new_img,light_orange,dark_orange)

# %%
result = cv2.bitwise_and(i,i,mask=(mask))

# %%
plt.figure(figsize=(32,32))
plt.subplot(1, 2, 1)
plt.xticks([]), plt.yticks([])
plt.imshow(mask)
plt.subplot(1, 2, 2)
plt.xticks([]), plt.yticks([])
plt.imshow(i)
plt.show()

# %%
img = cv2.imread('/home/pranavkdas/Documents/nemo.jpg')
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.show()
